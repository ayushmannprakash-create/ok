# %%
def create_employee_system():
    Batch_1 = {
        'Nitin Rajput': {'ID': 2223, 'Experience': '10 years', 'Salary': 2000000, 'Desk': 501},
        'Hashit Garg': {'ID': 2330, 'Experience': '2 years', 'Salary': 1500000, 'Desk': 502},
        'Rajendra Prasad': {'ID': 1110, 'Experience': '20 years', 'Salary': 3000000, 'Desk': 503}
    }
    Batch_2 = {
        'Vibhu Yadav': {'ID': 2345, 'Experience': '5 years', 'Salary': 1400000, 'Desk': 401},
        'Akansha Sinha': {'ID': 2200, 'Experience': '4 years', 'Salary': 1300000, 'Desk': 402},
        'Lakshya Rajput': {'ID': 2121, 'Experience': '3 years', 'Salary': 1200000, 'Desk': 403}
    }
    Batch_3_Internship = {
        'Lokesh Kamre': {'ID': 3000, 'Experience': '1 month', 'Salary': 30000, 'Desk': 101},
        'Ananya Pandey': {'ID': 3001, 'Experience': '2 months', 'Salary': 32000, 'Desk': 102},
        'Rajiv Rangan': {'ID': 3003, 'Experience': '4 months', 'Salary': 40000, 'Desk': 103}
    }


    system = {
        'Batch_1': Batch_1,
        'Batch_2': Batch_2,
        'Internship': Batch_3_Internship
    }
    return system

def add_new_member(system, batch_name, name, emp_id, exp, ann_sal, desk_no):
    if batch_name not in system:
        print(f" Error: Batch '{batch_name}' does not exist.")
        return False


    new_employee_data = {
        'ID': emp_id,
        'Experience': exp,
        'Salary': ann_sal,
        'Desk': desk_no
    }
    system[batch_name][name] = new_employee_data

    print(f" Success: {name} (ID: {emp_id}) added to {batch_name}.")
    return True
